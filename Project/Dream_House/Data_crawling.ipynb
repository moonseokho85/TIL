# %% [markdown]
# # 데이터 불러오기

# %%
import pandas as pd

# %%
# 초등학교 위치 데이터 불러오기
elementary_df = pd.read_excel('C:/Users/student/Data/2018년_공시대상학교정보(전체).xlsx')

# %%
elementary_df.head()
# Out:
#       시도교육청           지역교육청         지역 정보공시 \n 학교코드              학교명  학교급코드  \
# 0  서울특별시교육청             교육부  서울특별시 서초구   S000003511    서울교육대학교부설초등학교      2
# 1  서울특별시교육청             교육부  서울특별시 종로구   S000003563  서울대학교사범대학부설초등학교      2
# 2  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000737         서울개원초등학교      2
# 3  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000738         서울개일초등학교      2
# 4  서울특별시교육청  서울특별시강남서초교육지원청  서울특별시 강남구   S010000741         서울구룡초등학교      2
#
#   설립구분 학교특성 분교여부 설립유형  ...    우편번호  학교도로명 \n 우편번호         학교도로명 \n 주소  \
# 0   국립  NaN    N   부설  ...  137742          06639  서울특별시 서초구 서초중앙로 96
# 1   국립  NaN    N   부설  ...  110810          03087    서울특별시 종로구 대학로 64
# 2   공립  NaN    N   단설  ...  135810          06321    서울특별시 강남구 선릉로 29
# 3   공립  NaN    N   단설  ...  135804          06323   서울특별시 강남구 개포로 401
# 4   공립  NaN    N   단설  ...  135244          06305   서울특별시 강남구 개포로 263
#
#            학교도로명 \n 상세주소         위도          경도          전화번호          팩스번호  \
# ...

# %%
# 정리된 초등학교 위치 데이터
seoul_elementary_school_df = pd.read_csv('C:/Users/student/Data/seoul_element_school.csv')

# %%
seoul_elementary_school_df.head()
# Out:
#    Unnamed: 0              학교명         위도          경도    구    동
# 0           0    서울교육대학교부설초등학교  37.490739  127.015424  서초구  서초동
# 1           1  서울대학교사범대학부설초등학교  37.577017  127.003091  종로구  동숭동
# 2           2         서울개원초등학교  37.481618  127.058738  강남구  개포동
# 3           3         서울개일초등학교  37.486214  127.057742  강남구  개포동
# 4           4         서울구룡초등학교  37.481193  127.051755  강남구  개포동

# %% [markdown]
# # Crawling

# %% [markdown]
# 매물의 위도, 경도의 리스트를 가져오기
